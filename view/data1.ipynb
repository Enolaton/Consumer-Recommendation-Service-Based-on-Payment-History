# %%
from matplotlib import rc

rc('font', family='Malgun Gothic')

# %%
cd  \Users\Jay\Documents\GitHub\Consumer-Recommendation-Service-Based-on-Payment-History\output
# Out:
# c:\Users\Jay\Documents\GitHub\Consumer-Recommendation-Service-Based-on-Payment-History\output

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_all = pd.read_csv('all_category_summary_202201_202511.csv')
print(data_all.shape)
print(data_all.info())
print(data_all.isnull().sum())
print(data_all.head())
# Out:
# (3760, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3760 entries, 0 to 3759
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year_month       3760 non-null   int64
#  1   age_group        3760 non-null   object
#  2   sex              3760 non-null   object
#  3   card_tpbuz_nm_2  3760 non-null   object
#  4   amt              3760 non-null   int64
#  5   cnt              3760 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 176.4+ KB
# None
# year_month         0
# age_group          0
# sex                0
# card_tpbuz_nm_2    0
# amt                0
# cnt                0
# dtype: int64
#    year_month age_group sex card_tpbuz_nm_2          amt      cnt
# 0      202201       30대   F            간이주점   1432315527    38769
# 1      202201       30대   F            고기요리   7775325923   211491
# 2      202201       30대   F          디저트/음료  13030676471  1277531
# 3      202201       30대   F         별식/퓨전요리   1448624943    69825
# 4      202201       30대   F              분식   2874156204   247437

# %%
df_f_20s = data_all[(data_all['sex'] == 'F') & (data_all['age_group'] == '30대')]

cnt_by_food_f_30s = df_f_20s.groupby('card_tpbuz_nm_2')['cnt'].sum()

cnt_by_food_f_30s.sort_values(ascending=False)
# Out:
# card_tpbuz_nm_2
# 디저트/음료     75866084
# 한식         31530259
# 패스트푸드      14009901
# 분식         13387341
# 고기요리       10774652
# 일식/수산물      4861946
# 별식/퓨전요리     4741511
# 중식          3798740
# 간이주점        3561645
# 양식          2879051
# Name: cnt, dtype: int64

# %%
plt.figure(figsize=(7, 7))

cnt_by_food_f_30s.plot.pie(autopct='%1.1f%%')

plt.title("30대 여자의 카테고리별 카드 결제 횟수")

plt.ylabel('')

plt.show()

# %%
fig, axes = plt.subplots(2, 5, figsize=(14, 7))
axes = axes.flatten()

axes
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)
